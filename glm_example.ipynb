# %%
from utils.load_data import DataLoader

# %%
base_path = "/Users/jakubkempa/Documents/magisterka/ds000105_R2.0.2"

dl = DataLoader(base_path, subject="sub-1")
dl.t_r
# Out:
# 2.5

# %%
{f"run-{i}": ", ".join(x["trial_type"].unique()) for i, x in enumerate(dl.events)}
# Out:
# {'run-0': 'scissors, face, cat, shoe, house, scrambledpix, bottle, chair',
#  'run-1': 'face, cat, shoe, chair, scissors, bottle, house, scrambledpix',
#  'run-2': 'cat, scrambledpix, scissors, chair, bottle, shoe, face, house',
#  'run-3': 'shoe, house, chair, cat, face, scrambledpix, bottle, scissors',
#  'run-4': 'house, scissors, bottle, face, chair, shoe, cat, scrambledpix',
#  'run-5': 'house, scrambledpix, face, shoe, chair, cat, bottle, scissors',
#  'run-6': 'face, chair, scissors, shoe, scrambledpix, house, cat, bottle',
#  'run-7': 'face, scrambledpix, scissors, shoe, bottle, cat, chair, house',
#  'run-8': 'face, chair, cat, house, scrambledpix, shoe, bottle, scissors',
#  'run-9': 'face, cat, scrambledpix, house, scissors, chair, shoe, bottle',
#  'run-10': 'cat, scrambledpix, chair, bottle, shoe, house, face, scissors',
#  'run-11': 'bottle, house, chair, scrambledpix, face, shoe, cat, scissors'}
